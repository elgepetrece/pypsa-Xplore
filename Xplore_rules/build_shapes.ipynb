# %% [markdown]
# # Rule: **build_shapes**

# %% [markdown]
# **Outputs**
#
# - resources/`country_shapes.geojson`
# - resources/`offshore_shapes.geojson`
# - resources/`europe_shape.geojson`
# - resources/`nuts3_shapes.geojson`

# %%
######################################## Parameters

### Run
name = ''
prefix = ''

# %%
##### Import packages
import geopandas as gpd
import yaml



##### Read params.yaml
with open('../params.yaml', 'r') as configfile:
    params = yaml.safe_load(configfile)


##### Ignore warnings
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %% [markdown]
# ## `country_shapes.geojson`

# %% [markdown]
# Load the file.

# %%
file = f'country_shapes.geojson'
path = f'{params['rootpath']}/resources/{prefix}/{name}/'

country_shapes = gpd.read_file(path+file)

# %% [markdown]
# Show its content.

# %%
country_shapes.head()
# Out:
#   name                                           geometry
# 0   ES  MULTIPOLYGON (((-5.25861 36.31067, -5.26214 36...

# %% [markdown]
# How many regions are there in the file?

# %%
len(country_shapes)
# Out:
# 1

# %% [markdown]
# Represent the shapes.

# %%
country_shapes.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## `offshore_shapes.geojson`

# %% [markdown]
# Load the file.

# %%
file = f'offshore_shapes.geojson'
path = f'{params['rootpath']}/resources/{prefix}/{name}/'

offshore_shapes = gpd.read_file(path+file)

# %% [markdown]
# Show its content.

# %%
offshore_shapes.head()
# Out:
#   name                                           geometry
# 0   ES  MULTIPOLYGON (((-1.925 43.72917, -1.85833 43.6...

# %% [markdown]
# How many regions are there in the file?

# %%
len(offshore_shapes)
# Out:
# 1

# %% [markdown]
# Represent the shapes.

# %%
offshore_shapes.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## `europe_shape.geojson`

# %% [markdown]
# Load the file.

# %%
file = f'europe_shape.geojson'
path = f'{params['rootpath']}/resources/{prefix}/{name}/'

europe_shape = gpd.read_file(path+file)

# %% [markdown]
# Show its content.

# %%
europe_shape.head()
# Out:
#    index                                           geometry
# 0      0  POLYGON ((-7.44203 37.31517, -7.43953 37.3266,...

# %% [markdown]
# How many regions are there in the file?

# %%
len(europe_shape)
# Out:
# 1

# %% [markdown]
# Represent the shapes.

# %%
europe_shape.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## `nuts3_shapes.geojson`

# %% [markdown]
# Load the file.

# %%
file = f'nuts3_shapes.geojson'
path = f'{params['rootpath']}/resources/{prefix}/{name}/'

nuts3_shapes = gpd.read_file(path+file)

# %% [markdown]
# Show its content.

# %%
nuts3_shapes.head()
# Out:
#    index       name level1 level2 level3      gdp     pop country  \
# 0  ES512     Girona    ES5   ES51  ES512  28308.0   771.0      ES
# 1  ES532   Mallorca    ES5   ES53  ES532  30166.0   909.0      ES
# 2  ES533    Menorca    ES5   ES53  ES533  21647.0    95.0      ES
# 3  ES511  Barcelona    ES5   ES51  ES511  31679.0  5657.0      ES
# 4  ES431    Badajoz    ES4   ES43  ES431  18600.0   673.0      ES
#
#                                             geometry
# 0  MULTIPOLYGON (((1.81604 42.48386, 1.82321 42.4...
# 1  POLYGON ((3.21144 39.9545, 3.20213 39.94454, 3...
# 2  POLYGON ((4.10726 40.04684, 4.11141 40.05391, ...
# 3  MULTIPOLYGON (((1.93971 42.31562, 1.94334 42.3...
# 4  POLYGON ((-4.70968 39.34647, -4.70666 39.32907...

# %% [markdown]
# How many regions are there in the file?

# %%
len(nuts3_shapes)
# Out:
# 50

# %% [markdown]
# Represent the shapes.

# %%
nuts3_shapes.plot()
# Out:
# <Axes: >
