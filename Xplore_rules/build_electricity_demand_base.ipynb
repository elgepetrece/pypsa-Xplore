# %% [markdown]
# # Rule: **build_electricity_demand_base**

# %% [markdown]
# **Outputs**
#
# - resources/`electricity_demand_base_s.nc`

# %%
######################################## Parameters

### Run
name = ''
prefix = ''

# %%
##### Import packages
import xarray as xr
import yaml



##### Read params.yaml
with open('../params.yaml', 'r') as configfile:
    params = yaml.safe_load(configfile)



##### Ignore warnings
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %% [markdown]
# ## `electricity_demand_base_s.nc`

# %% [markdown]
# Load the network and show its components.

# %%
file = f'electricity_demand_base_s.nc'
path = f'{params['rootpath']}/resources/{prefix}/{name}/'

ds = xr.open_dataset(path+file)

# %%
print(ds)
# Out:
# <xarray.Dataset> Size: 39MB
# Dimensions:                  (time: 8760, bus: 555)
# Coordinates:
#   * time                     (time) datetime64[ns] 70kB 2013-01-01 ... 2013-1...
#   * bus                      (bus) <U21 47kB 'ES1-400' ... 'way/991952490-220'
# Data variables:
#     electricity demand (MW)  (time, bus) float64 39MB ...

# %%
ds['electricity demand (MW)'].sum(dim='bus').plot()
